# %%
import json
import gzip
import pandas as pd

with open("pubmed-dataset/test.txt", mode="r") as f:
    data = [json.loads(line.rstrip('\n')) for line in f]
    #data = f.readline()
    #data = f.read()

# %%
df = pd.DataFrame(data)
# Out:
#       article_id                                       article_text  \
# 0     PMC5075302  [anxiety affects quality of life in those livi...
# 1     PMC3309138  [small non - coding rnas are transcribed into ...
# 2     PMC4086000  [ohss is a serious complication of ovulation i...
# 3     PMC3603086  [congenital adrenal hyperplasia ( cah ) refers...
# 4     PMC4414990  [type 1 diabetes ( t1d ) results from the dest...
# ...          ...                                                ...
# 6653  PMC2817809  [neurocysticercosis is the most common parasit...
# 6654  PMC5421177  [most chd prevalence data are based on populat...
# 6655  PMC3336056  [renal transplantation rates are low among pat...
# 6656  PMC4461384  [acute kidney injury ( aki ) , defined as an a...
# 6657  PMC4637496  [human brain plasticity or neuroplasticity ref...
#
#                                           abstract_text labels  \
# 0     [<S> research on the implications of anxiety i...   None
# ...
